# %% [markdown]
# # Loading

# %%
# !pip install scltnn
# !pip install scvelo
# !pip install pyomic
# !pip install anndata
# !pip3 install leidenalg
# !pip install sccoda
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scltnn
#   Downloading scltnn-0.0.8-py3-none-any.whl (27 kB)
# Collecting scanpy>=1.9
#   Downloading scanpy-1.9.1-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 7.4 MB/s
# Collecting numpy>=1.22
#   Downloading numpy-1.24.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 40.5 MB/s
# Collecting distfit
#   Downloading distfit-1.4.5-py3-none-any.whl (22 kB)
# Collecting pandas>=1.4
#   Downloading pandas-1.5.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      |████████████████████████████████| 12.2 MB 68.9 MB/s
# Requirement already satisfied: keras>=2.8 in /usr/local/lib/python3.8/dist-packages (from scltnn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.4->scltnn) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.4->scltnn) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas>=1.4->scltnn) (1.15.0)
# Collecting anndata>=0.7.4
#   Downloading anndata-0.8.0-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 4.8 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (1.2.0)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (0.56.4)
# Requirement already satisfied: patsy in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (0.5.3)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (2.8.8)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (0.11.2)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (5.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (21.3)
# Collecting session-info
#   Downloading session_info-1.0.0.tar.gz (24 kB)
# Collecting matplotlib>=3.4
#   Downloading matplotlib-3.6.2-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      |████████████████████████████████| 9.4 MB 55.1 MB/s
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (3.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (4.64.1)
# Collecting umap-learn>=0.3.10
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 7.6 MB/s
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (1.0.2)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (0.12.2)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.9->scltnn) (1.7.3)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 48.9 MB/s
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy>=1.9->scltnn) (0.11.0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (295 kB)
#      |████████████████████████████████| 295 kB 72.2 MB/s
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy>=1.9->scltnn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy>=1.9->scltnn) (7.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy>=1.9->scltnn) (3.0.9)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy>=1.9->scltnn) (0.39.1)
# Collecting numpy>=1.22
#   Downloading numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      |████████████████████████████████| 17.1 MB 58.5 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy>=1.9->scltnn) (5.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy>=1.9->scltnn) (57.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->scanpy>=1.9->scltnn) (3.1.0)
#   Downloading numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
#      |████████████████████████████████| 16.9 MB 69.2 MB/s
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 57.9 MB/s
# Collecting pypickle
#   Downloading pypickle-1.1.0-py3-none-any.whl (5.1 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.41.0->scanpy>=1.9->scltnn) (3.11.0)
# Collecting stdlib_list
#   Downloading stdlib_list-0.8.0-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.0 MB/s
# Building wheels for collected packages: umap-learn, pynndescent, session-info
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=100175a8d1105ee5f71be7b1e75c3ef90e9d8e06d199158400467fd78da7f7cd
#   Stored in directory: /root/.cache/pip/wheels/a9/3a/67/06a8950e053725912e6a8c42c4a3a241410f6487b8402542ea
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=9dcfb758775811cc4093d8cb4cdcc2419a75e9192e03a0678f49c6516095cd83
#   Stored in directory: /root/.cache/pip/wheels/1c/63/3a/29954bca1a27ba100ed8c27973a78cb71b43dc67aed62e80c3
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8046 sha256=58704231de58cce3294d3c54b8b0a572c1188cd0ebfae76c27df80e44f57537f
#   Stored in directory: /root/.cache/pip/wheels/5c/1b/4d/111d73980c5c6a8e5e5905a19eccc34296cb359cac54c6c5b9
# Successfully built umap-learn pynndescent session-info
# Installing collected packages: numpy, fonttools, contourpy, stdlib-list, pynndescent, pandas, matplotlib, umap-learn, session-info, pypickle, anndata, scanpy, distfit, scltnn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# Successfully installed anndata-0.8.0 contourpy-1.0.6 distfit-1.4.5 fonttools-4.38.0 matplotlib-3.6.2 numpy-1.22.4 pandas-1.5.2 pynndescent-0.5.8 pypickle-1.1.0 scanpy-1.9.1 scltnn-0.0.8 session-info-1.0.0 stdlib-list-0.8.0 umap-learn-0.5.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scvelo
#   Downloading scvelo-0.2.5-py3-none-any.whl (219 kB)
#      |████████████████████████████████| 219 kB 4.8 MB/s
# Requirement already satisfied: scanpy>=1.5 in /usr/local/lib/python3.8/dist-packages (from scvelo) (1.9.1)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.8/dist-packages (from scvelo) (0.56.4)
# Collecting loompy>=2.0.12
#   Downloading loompy-3.0.7.tar.gz (4.8 MB)
#      |████████████████████████████████| 4.8 MB 66.3 MB/s
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from scvelo) (1.7.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from scvelo) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.21.2 in /usr/local/lib/python3.8/dist-packages (from scvelo) (1.0.2)
# Requirement already satisfied: pandas!=1.4.0,>=0.23 in /usr/local/lib/python3.8/dist-packages (from scvelo) (1.5.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from scvelo) (4.4.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.8/dist-packages (from scvelo) (3.6.2)
# Requirement already satisfied: umap-learn>=0.3.10 in /usr/local/lib/python3.8/dist-packages (from scvelo) (0.5.3)
# Requirement already satisfied: anndata>=0.7.5 in /usr/local/lib/python3.8/dist-packages (from scvelo) (0.8.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.8/dist-packages (from anndata>=0.7.5->scvelo) (21.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from anndata>=0.7.5->scvelo) (5.5.0)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.8/dist-packages (from anndata>=0.7.5->scvelo) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from loompy>=2.0.12->scvelo) (57.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from loompy>=2.0.12->scvelo) (7.1.2)
# Collecting numpy-groupies
#   Downloading numpy_groupies-0.9.20-py3-none-any.whl (25 kB)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->scvelo) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->scvelo) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->scvelo) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->scvelo) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->scvelo) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->scvelo) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.0->scvelo) (4.38.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scvelo) (5.1.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scvelo) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas!=1.4.0,>=0.23->scvelo) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->scvelo) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.5->scvelo) (1.2.0)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.5->scvelo) (0.12.2)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.5->scvelo) (2.8.8)
# Requirement already satisfied: patsy in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.5->scvelo) (0.5.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.5->scvelo) (0.11.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.5->scvelo) (4.64.1)
# Requirement already satisfied: session-info in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.5->scvelo) (1.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.2->scvelo) (3.1.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.8/dist-packages (from umap-learn>=0.3.10->scvelo) (0.5.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.41.0->scvelo) (3.11.0)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.8/dist-packages (from session-info->scanpy>=1.5->scvelo) (0.8.0)
# Building wheels for collected packages: loompy
#   Building wheel for loompy (setup.py) ... done
#   Created wheel for loompy: filename=loompy-3.0.7-py3-none-any.whl size=52040 sha256=1d048a3e7a43bd0eb8788561a152bb7495c1150fe24aa02760b95e4ec33b93bf
#   Stored in directory: /root/.cache/pip/wheels/51/a8/38/34cd3ac301d305904452deca6780940beb70d059798042fd63
# Successfully built loompy
# Installing collected packages: numpy-groupies, loompy, scvelo
# Successfully installed loompy-3.0.7 numpy-groupies-0.9.20 scvelo-0.2.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyomic
#   Downloading Pyomic-1.1.5-py3-none-any.whl (15.6 MB)
#      |████████████████████████████████| 15.6 MB 5.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pyomic) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pyomic) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from pyomic) (1.5.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from pyomic) (0.11.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from pyomic) (2.8.8)
# Collecting datetime
#   Downloading DateTime-4.9-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.1 MB/s
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.8/dist-packages (from pyomic) (0.12.2)
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
# Collecting gseapy==0.10.8
#   Downloading gseapy-0.10.8-py3-none-any.whl (526 kB)
#      |████████████████████████████████| 526 kB 67.9 MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from pyomic) (3.6.2)
# Requirement already satisfied: scanpy in /usr/local/lib/python3.8/dist-packages (from pyomic) (1.9.1)
# Collecting ERgene
#   Downloading ERgene-1.2.8-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from gseapy==0.10.8->pyomic) (1.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from gseapy==0.10.8->pyomic) (2.23.0)
# Collecting bioservices
#   Downloading bioservices-1.11.0.tar.gz (190 kB)
#      |████████████████████████████████| 190 kB 61.0 MB/s
# Requirement already satisfied: appdirs in /usr/local/lib/python3.8/dist-packages (from bioservices->gseapy==0.10.8->pyomic) (1.4.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from bioservices->gseapy==0.10.8->pyomic) (4.6.3)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting easydev>=0.12.0
#   Downloading easydev-0.12.0.tar.gz (47 kB)
#      |████████████████████████████████| 47 kB 4.0 MB/s
# Collecting grequests
#   Downloading grequests-0.6.0-py3-none-any.whl (5.2 kB)
# Collecting requests_cache
#   Downloading requests_cache-0.9.7-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 4.7 MB/s
# Collecting suds-community>=0.7
#   Downloading suds_community-1.1.2-py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 70.8 MB/s
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from bioservices->gseapy==0.10.8->pyomic) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from bioservices->gseapy==0.10.8->pyomic) (4.64.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.8/dist-packages (from bioservices->gseapy==0.10.8->pyomic) (1.14.1)
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from easydev>=0.12.0->bioservices->gseapy==0.10.8->pyomic) (4.8.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas->pyomic) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas->pyomic) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas->pyomic) (1.15.0)
# Collecting zope.interface
#   Downloading zope.interface-5.5.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (261 kB)
#      |████████████████████████████████| 261 kB 53.8 MB/s
# Collecting upsetplot
#   Downloading UpSetPlot-0.7.0.tar.gz (20 kB)
# Collecting gevent
#   Downloading gevent-22.10.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 75.3 MB/s
# Collecting zope.event
#   Downloading zope.event-4.6-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: greenlet>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from gevent->grequests->bioservices->gseapy==0.10.8->pyomic) (2.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from gevent->grequests->bioservices->gseapy==0.10.8->pyomic) (57.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyomic) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyomic) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyomic) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyomic) (7.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyomic) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyomic) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyomic) (1.0.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->easydev>=0.12.0->bioservices->gseapy==0.10.8->pyomic) (0.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->gseapy==0.10.8->pyomic) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->gseapy==0.10.8->pyomic) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->gseapy==0.10.8->pyomic) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->gseapy==0.10.8->pyomic) (1.24.3)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.8/dist-packages (from requests_cache->bioservices->gseapy==0.10.8->pyomic) (22.1.0)
# Collecting cattrs>=22.2
#   Downloading cattrs-22.2.0-py3-none-any.whl (35 kB)
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 60.5 MB/s
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: umap-learn>=0.3.10 in /usr/local/lib/python3.8/dist-packages (from scanpy->pyomic) (0.5.3)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.8/dist-packages (from scanpy->pyomic) (3.1.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.8/dist-packages (from scanpy->pyomic) (0.5.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from scanpy->pyomic) (5.5.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from scanpy->pyomic) (1.0.2)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.8/dist-packages (from scanpy->pyomic) (0.56.4)
# Requirement already satisfied: session-info in /usr/local/lib/python3.8/dist-packages (from scanpy->pyomic) (1.0.0)
# Requirement already satisfied: anndata>=0.7.4 in /usr/local/lib/python3.8/dist-packages (from scanpy->pyomic) (0.8.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy->pyomic) (5.1.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy->pyomic) (0.39.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->scanpy->pyomic) (3.1.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.8/dist-packages (from umap-learn>=0.3.10->scanpy->pyomic) (0.5.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.41.0->scanpy->pyomic) (3.11.0)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.8/dist-packages (from session-info->scanpy->pyomic) (0.8.0)
# Building wheels for collected packages: bioservices, easydev, sklearn, upsetplot
#   Building wheel for bioservices (setup.py) ... done
#   Created wheel for bioservices: filename=bioservices-1.11.0-py3-none-any.whl size=221946 sha256=8c533ee524cdd3abdfb15d6b38ce52fb447d00aecf75e6ef7f8ef64e51d291c3
#   Stored in directory: /root/.cache/pip/wheels/21/53/2d/3eff1919e1497f2138fe865eef9fb40c48bb6ac4e101e82293
#   Building wheel for easydev (setup.py) ... done
#   Created wheel for easydev: filename=easydev-0.12.0-py3-none-any.whl size=64232 sha256=10a7345a725dfc9ae990042b955345d545b2f0fd57bf9d05edce8efe30f97e2a
#   Stored in directory: /root/.cache/pip/wheels/e2/47/9f/de01f291cfde341b33383bcf1292b17d64c700d4a12b318a7d
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=45b23cacf96c4f1b4d57303e88432726465e54f74db15f90d12973b5e5aeef2d
#   Stored in directory: /root/.cache/pip/wheels/14/25/f7/1cc0956978ae479e75140219088deb7a36f60459df242b1a72
#   Building wheel for upsetplot (setup.py) ... done
#   Created wheel for upsetplot: filename=UpSetPlot-0.7.0-py3-none-any.whl size=21329 sha256=b4ae1afe763de76c24270e286ca2213637a53477f6bf17d58b79a2506d75b688
#   Stored in directory: /root/.cache/pip/wheels/ee/7c/ff/b402390c8ce32baafba1bfcb255f18e68b688dad6e86259df5
# Successfully built bioservices easydev sklearn upsetplot
# Installing collected packages: zope.interface, zope.event, urllib3, exceptiongroup, url-normalize, gevent, colorlog, colorama, cattrs, xmltodict, suds-community, requests-cache, grequests, easydev, upsetplot, bioservices, sklearn, gseapy, ERgene, datetime, pyomic
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed ERgene-1.2.8 bioservices-1.11.0 cattrs-22.2.0 colorama-0.4.6 colorlog-6.7.0 datetime-4.9 easydev-0.12.0 exceptiongroup-1.1.0 gevent-22.10.2 grequests-0.6.0 gseapy-0.10.8 pyomic-1.1.5 requests-cache-0.9.7 sklearn-0.0.post1 suds-community-1.1.2 upsetplot-0.7.0 url-normalize-1.4.3 urllib3-1.25.11 xmltodict-0.13.0 zope.event-4.6 zope.interface-5.5.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: anndata in /usr/local/lib/python3.8/dist-packages (0.8.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.8/dist-packages (from anndata) (21.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.8/dist-packages (from anndata) (1.22.4)
# Requirement already satisfied: pandas>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from anndata) (1.5.2)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.8/dist-packages (from anndata) (3.1.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from anndata) (5.5.0)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.8/dist-packages (from anndata) (1.7.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20->anndata) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.1->anndata) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.1->anndata) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.1->anndata) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting leidenalg
#   Downloading leidenalg-0.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 4.7 MB/s
# Collecting igraph<0.11,>=0.10.0
#   Downloading igraph-0.10.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 43.0 MB/s
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph, leidenalg
# Successfully installed igraph-0.10.2 leidenalg-0.9.1 texttable-1.6.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sccoda
#   Downloading scCODA-0.1.8-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.4 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from sccoda) (1.7.3)
# Requirement already satisfied: anndata in /usr/local/lib/python3.8/dist-packages (from sccoda) (0.8.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.8/dist-packages (from sccoda) (0.0.post1)
# Requirement already satisfied: rpy2 in /usr/local/lib/python3.8/dist-packages (from sccoda) (3.5.5)
# Requirement already satisfied: tensorflow>=2.8 in /usr/local/lib/python3.8/dist-packages (from sccoda) (2.9.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.8/dist-packages (from sccoda) (1.22.4)
# Requirement already satisfied: tensorflow-probability>=0.16.0 in /usr/local/lib/python3.8/dist-packages (from sccoda) (0.17.0)
# Requirement already satisfied: arviz>=0.11 in /usr/local/lib/python3.8/dist-packages (from sccoda) (0.12.1)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.8/dist-packages (from sccoda) (1.5.2)
# Requirement already satisfied: scanpy in /usr/local/lib/python3.8/dist-packages (from sccoda) (1.9.1)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.8/dist-packages (from sccoda) (3.6.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.8/dist-packages (from sccoda) (0.12.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from sccoda) (0.11.2)
# Requirement already satisfied: patsy in /usr/local/lib/python3.8/dist-packages (from sccoda) (0.5.3)
# Requirement already satisfied: xarray>=0.16.1 in /usr/local/lib/python3.8/dist-packages (from arviz>=0.11->sccoda) (2022.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from arviz>=0.11->sccoda) (4.4.0)
# Requirement already satisfied: xarray-einstats>=0.2 in /usr/local/lib/python3.8/dist-packages (from arviz>=0.11->sccoda) (0.4.0)
# Requirement already satisfied: setuptools>=38.4 in /usr/local/lib/python3.8/dist-packages (from arviz>=0.11->sccoda) (57.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from arviz>=0.11->sccoda) (21.3)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.8/dist-packages (from arviz>=0.11->sccoda) (1.6.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0->sccoda) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0->sccoda) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0->sccoda) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0->sccoda) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0->sccoda) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0->sccoda) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.0->sccoda) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0->sccoda) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->sccoda) (1.15.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (3.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (0.28.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (1.6.3)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (2.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (14.0.6)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (2.9.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (2.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (3.19.6)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (1.14.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (1.12)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (1.51.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8->sccoda) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8->sccoda) (0.38.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (2.15.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (2022.12.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.8->sccoda) (3.2.2)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability>=0.16.0->sccoda) (0.1.7)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability>=0.16.0->sccoda) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability>=0.16.0->sccoda) (1.5.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from anndata->sccoda) (5.5.0)
# Requirement already satisfied: cftime in /usr/local/lib/python3.8/dist-packages (from netcdf4->arviz>=0.11->sccoda) (1.6.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.8/dist-packages (from rpy2->sccoda) (1.5.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from rpy2->sccoda) (2.11.3)
# Requirement already satisfied: cffi>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from rpy2->sccoda) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.10.0->rpy2->sccoda) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->rpy2->sccoda) (2.0.1)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.8/dist-packages (from scanpy->sccoda) (2.8.8)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from scanpy->sccoda) (1.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from scanpy->sccoda) (4.64.1)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.8/dist-packages (from scanpy->sccoda) (0.56.4)
# Requirement already satisfied: umap-learn>=0.3.10 in /usr/local/lib/python3.8/dist-packages (from scanpy->sccoda) (0.5.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from scanpy->sccoda) (1.2.0)
# Requirement already satisfied: session-info in /usr/local/lib/python3.8/dist-packages (from scanpy->sccoda) (1.0.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy->sccoda) (0.39.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->scanpy->sccoda) (3.1.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.8/dist-packages (from umap-learn>=0.3.10->scanpy->sccoda) (0.5.8)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.8/dist-packages (from session-info->scanpy->sccoda) (0.8.0)
# Installing collected packages: sccoda
# Successfully installed sccoda-0.1.8

# %%
#导入包
import anndata
print('anndata(Ver): ',anndata.__version__)
import scanpy as sc
print('scanpy(Ver): ',sc.__version__)
import scltnn #非必需
print('scltnn(Ver): ',scltnn.__version__)
import matplotlib.pyplot as plt
import matplotlib
print('matplotlib(Ver): ',matplotlib.__version__)
import seaborn as sns
print('seaborn(Ver): ',sns.__version__)
import numpy as np
print('numpy(Ver): ',np.__version__)
import pandas as pd
print('pandas(Ver): ',pd.__version__)
import scvelo as scv
print('scvelo(Ver): ',scv.__version__)
import Pyomic
print('Pyomic(Ver): ',Pyomic.__version__)
# Out:
# anndata(Ver):  0.8.0
# scanpy(Ver):  1.9.1
# scltnn(Ver):  0.0.8
# matplotlib(Ver):  3.6.2
# seaborn(Ver):  0.11.2
# numpy(Ver):  1.22.4
# pandas(Ver):  1.5.2
# scvelo(Ver):  0.2.5
# Creating directory /root/.config/bioservices
# Pyomic(Ver):  1.1.5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sc_color=['#7CBB5F',
 '#368650',
 '#A499CC',
 '#5E4D9A',
 '#78C2ED',
 '#866017',
 '#9F987F',
 '#E0DFED',
 '#EF7B77',
 '#279AD7',
 '#F0EEF0',
 '#1F577B',
 '#A56BA7',
 '#E0A7C8',
 '#E069A6',
 '#941456',
 '#FCBC10',
 '#EAEFC5',
 '#01A0A7',
 '#75C8CC',
 '#F0D7BC',
 '#D5B26C',
 '#D5DA48',
 '#B6B812',
 '#9DC3C3',
 '#A89C92',
 '#FEE00C',
 '#FEF2A1']

# %%
#绘图参数设置
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80, facecolor='white')

# %%
adata = sc.read('/content/drive/MyDrive/Gastric/NKT/Data/Gastric_NKT_anno.h5ad',compression='gzip')
# Out:
# /usr/local/lib/python3.8/dist-packages/h5py/_hl/dataset.py:767: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
#   arr = numpy.ndarray(selection.mshape, dtype=new_dtype)

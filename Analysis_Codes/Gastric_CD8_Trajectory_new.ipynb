# %% [markdown]
# # Loading

# %%
# !pip install scanpy
# !pip install anndata
# !pip install pyVIA
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scanpy
#   Downloading scanpy-1.9.1-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.21.6)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from scanpy) (5.5.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.2.0)
# Collecting anndata>=0.7.4
#   Downloading anndata-0.8.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.3.5)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.7.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from scanpy) (23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from scanpy) (4.64.1)
# Collecting session-info
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: patsy in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.5.3)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.8/dist-packages (from scanpy) (3.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.0.2)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.12.2)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.8/dist-packages (from scanpy) (3.1.0)
# Collecting matplotlib>=3.4
#   Downloading matplotlib-3.6.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 30.6 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.56.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.11.2)
# Collecting umap-learn>=0.3.10
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (3.0.9)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 KB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (7.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (6.0.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (0.39.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0->scanpy) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->scanpy) (3.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy->scanpy) (1.15.0)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting stdlib_list
#   Downloading stdlib_list-0.8.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 KB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.41.0->scanpy) (3.12.0)
# Building wheels for collected packages: umap-learn, session-info, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=f6822d3664f6c05308bcd3d955bee5847df1b96da474048b16e50851206b24bb
#   Stored in directory: /root/.cache/pip/wheels/a9/3a/67/06a8950e053725912e6a8c42c4a3a241410f6487b8402542ea
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8046 sha256=8dde9b18c7163b8e035b136c1f9d7ec4a6b60e6dd168ec0210fed2c7b922da56
#   Stored in directory: /root/.cache/pip/wheels/5c/1b/4d/111d73980c5c6a8e5e5905a19eccc34296cb359cac54c6c5b9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=f669cd880efce712bb699524a99e6838a21a41ed5fbd6234b8b295341a54b7de
#   Stored in directory: /root/.cache/pip/wheels/1c/63/3a/29954bca1a27ba100ed8c27973a78cb71b43dc67aed62e80c3
# Successfully built umap-learn session-info pynndescent
# Installing collected packages: stdlib_list, session-info, fonttools, contourpy, matplotlib, pynndescent, anndata, umap-learn, scanpy
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# Successfully installed anndata-0.8.0 contourpy-1.0.7 fonttools-4.38.0 matplotlib-3.6.3 pynndescent-0.5.8 scanpy-1.9.1 session-info-1.0.0 stdlib_list-0.8.0 umap-learn-0.5.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: anndata in /usr/local/lib/python3.8/dist-packages (0.8.0)
# Requirement already satisfied: pandas>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from anndata) (1.3.5)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.8/dist-packages (from anndata) (23.0)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.8/dist-packages (from anndata) (3.1.0)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.8/dist-packages (from anndata) (1.7.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.8/dist-packages (from anndata) (1.21.6)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from anndata) (5.5.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.1->anndata) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.1->anndata) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.1->anndata) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyVIA
#   Downloading pyVIA-0.1.73-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.3/140.3 KB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from pyVIA) (1.3.5)
# Collecting hnswlib
#   Downloading hnswlib-0.6.2.tar.gz (31 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from pyVIA) (3.6.3)
# Collecting pygam
#   Downloading pygam-0.8.0-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 35.3 MB/s eta 0:00:00
# Collecting pybind11
#   Using cached pybind11-2.10.3-py3-none-any.whl (222 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from pyVIA) (7.1.2)
# Requirement already satisfied: scanpy in /usr/local/lib/python3.8/dist-packages (from pyVIA) (1.9.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from pyVIA) (1.0.2)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.8/dist-packages (from pyVIA) (0.5.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.8/dist-packages (from pyVIA) (0.18.3)
# Collecting datashader
#   Downloading datashader-0.14.4-py2.py3-none-any.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 64.7 MB/s eta 0:00:00
# Collecting leidenalg>=0.7.0
#   Downloading leidenalg-0.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.3 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (from pyVIA) (4.4.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from pyVIA) (0.11.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pyVIA) (1.7.3)
# Collecting phate
#   Downloading phate-1.0.10-py3-none-any.whl (23 kB)
# Collecting igraph
#   Downloading igraph-0.10.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 71.6 MB/s eta 0:00:00
# Requirement already satisfied: termcolor in /usr/local/lib/python3.8/dist-packages (from pyVIA) (2.2.0)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from pyVIA) (1.21.6)
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->pyVIA) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->pyVIA) (2.8.2)
# Requirement already satisfied: pyct in /usr/local/lib/python3.8/dist-packages (from datashader->pyVIA) (0.5.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from datashader->pyVIA) (0.12.0)
# Requirement already satisfied: dask in /usr/local/lib/python3.8/dist-packages (from datashader->pyVIA) (2022.2.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.8/dist-packages (from datashader->pyVIA) (2022.12.0)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.8/dist-packages (from datashader->pyVIA) (3.0.1)
# Requirement already satisfied: param in /usr/local/lib/python3.8/dist-packages (from datashader->pyVIA) (1.12.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from datashader->pyVIA) (2.25.1)
# Collecting datashape
#   Downloading datashape-0.5.2.tar.gz (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 KB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.8/dist-packages (from datashader->pyVIA) (0.56.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown->pyVIA) (3.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown->pyVIA) (4.6.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown->pyVIA) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from gdown->pyVIA) (4.64.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyVIA) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyVIA) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyVIA) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyVIA) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyVIA) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyVIA) (0.11.0)
# Collecting Deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting scprep>=0.11.1
#   Downloading scprep-1.2.2-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.8/93.8 KB 6.3 MB/s eta 0:00:00
# Collecting s-gd2>=1.8.1
#   Downloading s_gd2-1.8.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (419 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.4/419.4 KB 33.0 MB/s eta 0:00:00
# Collecting tasklogger>=1.0
#   Downloading tasklogger-1.2.0-py3-none-any.whl (14 kB)
# Collecting graphtools>=1.5.3
#   Downloading graphtools-1.5.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 KB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from phate->pyVIA) (0.16.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->pyVIA) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->pyVIA) (3.1.0)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.8/dist-packages (from pygam->pyVIA) (3.38.0)
# Requirement already satisfied: anndata>=0.7.4 in /usr/local/lib/python3.8/dist-packages (from scanpy->pyVIA) (0.8.0)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.8/dist-packages (from scanpy->pyVIA) (3.1.0)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.8/dist-packages (from scanpy->pyVIA) (0.12.2)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.8/dist-packages (from scanpy->pyVIA) (3.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.8/dist-packages (from scanpy->pyVIA) (0.5.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from scanpy->pyVIA) (5.5.0)
# Requirement already satisfied: session-info in /usr/local/lib/python3.8/dist-packages (from scanpy->pyVIA) (1.0.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.8/dist-packages (from umap-learn->pyVIA) (0.5.8)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image->pyVIA) (1.4.1)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image->pyVIA) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.8/dist-packages (from scikit-image->pyVIA) (2023.1.23.1)
# Collecting pygsp>=0.5.1
#   Downloading PyGSP-0.5.1-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 54.7 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.51->datashader->pyVIA) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.51->datashader->pyVIA) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.51->datashader->pyVIA) (6.0.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from scprep>=0.11.1->phate->pyVIA) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from dask->datashader->pyVIA) (2.2.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from dask->datashader->pyVIA) (2023.1.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.8/dist-packages (from dask->datashader->pyVIA) (1.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from dask->datashader->pyVIA) (6.0)
# Requirement already satisfied: multipledispatch>=0.4.7 in /usr/local/lib/python3.8/dist-packages (from datashape->datashader->pyVIA) (0.6.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.8/dist-packages (from Deprecated->phate->pyVIA) (1.14.1)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from progressbar2->pygam->pyVIA) (3.4.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->datashader->pyVIA) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->datashader->pyVIA) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->datashader->pyVIA) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->datashader->pyVIA) (4.0.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests->datashader->pyVIA) (1.7.1)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.8/dist-packages (from session-info->scanpy->pyVIA) (0.8.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.8/dist-packages (from partd>=0.3.10->dask->datashader->pyVIA) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.51->datashader->pyVIA) (3.12.0)
# Building wheels for collected packages: hnswlib, wget, datashape
#   Building wheel for hnswlib (pyproject.toml) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.6.2-cp38-cp38-linux_x86_64.whl size=2042773 sha256=1691a5a68eae5933636e69c2355e73a3574147fc33ccc299e6c28514e7c17b68
#   Stored in directory: /root/.cache/pip/wheels/74/3b/89/4bd924865709f24ac2df457bcca4c0b55a3eb89c5a94ce3ce8
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=7bda47ff58e883062ba91a0365317fb1a1bd25780f2bf12267134b9b6660f1d0
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
#   Building wheel for datashape (setup.py) ... done
#   Created wheel for datashape: filename=datashape-0.5.2-py3-none-any.whl size=59439 sha256=e7b044039bf0c3bcff5dab7019ee2c6edb85e8ab8232567ab68fd989f4af4fb2
#   Stored in directory: /root/.cache/pip/wheels/6d/79/c4/c425774559165f472d32e5ef592ff9a71179abb31f05dbc98b
# Successfully built hnswlib wget datashape
# Installing collected packages: wget, texttable, s-gd2, pybind11, igraph, hnswlib, Deprecated, tasklogger, pygsp, pygam, leidenalg, datashape, scprep, graphtools, phate, datashader, pyVIA
# Successfully installed Deprecated-1.2.13 datashader-0.14.4 datashape-0.5.2 graphtools-1.5.3 hnswlib-0.6.2 igraph-0.10.4 leidenalg-0.9.1 phate-1.0.10 pyVIA-0.1.73 pybind11-2.10.3 pygam-0.8.0 pygsp-0.5.1 s-gd2-1.8.1 scprep-1.2.2 tasklogger-1.2.0 texttable-1.6.7 wget-3.2

# %%
from pyVIA.core import *
import pyVIA.datasets_via as datasets_via
#from core_working_ import *
import pandas as pd
import umap
import scanpy as sc
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7d66f213303f> in <module>
# ----> 1 from pyVIA.core import *
#       2 import pyVIA.datasets_via as datasets_via
#       3 #from core_working_ import *
#       4 import pandas as pd
#       5 import umap
#
# /usr/local/lib/python3.8/dist-packages/pyVIA/__init__.py in <module>
# ----> 1 from . import core
#       2 from . import examples
#       3 from . import utils_via
#       4 from . import windmap
#       5 from . import plotting_via
#
# /usr/local/lib/python3.8/dist-packages/pyVIA/core.py in <module>
#      20 from collections import Counter
#      21 from typing import Optional, Union
# ---> 22 from pyVIA.plotting_via import *
#      23 from pyVIA.utils_via import _construct_knn, sequential_knn
#      24 from pyVIA.utils_via import *
#
# /usr/local/lib/python3.8/dist-packages/pyVIA/plotting_via.py in <module>
#       4 from datetime import datetime
#       5 from scipy.stats import norm as normal
# ----> 6 from mpl_toolkits.axes_grid1 import make_axes_locatable
#       7 from scipy.spatial import distance
#       8 from scipy.sparse import csr_matrix, csgraph, find
#
# /usr/local/lib/python3.8/dist-packages/mpl_toolkits/axes_grid1/__init__.py in <module>
#       1 from . import axes_size as Size
#       2 from .axes_divider import Divider, SubplotDivider, make_axes_locatable
# ----> 3 from .axes_grid import AxesGrid, Grid, ImageGrid
#       4
#       5 from .parasite_axes import host_subplot, host_axes
#
# /usr/local/lib/python3.8/dist-packages/mpl_toolkits/axes_grid1/axes_grid.py in <module>
#      47
#      48
# ---> 49 _cbaraxes_class_factory = cbook._make_class_factory(CbarAxesBase, "Cbar{}")
#      50
#      51
#
# AttributeError: module 'matplotlib.cbook' has no attribute '_make_class_factory'

# %%
#绘图参数设置
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80, facecolor='white')

# %%
# !git clone https://github.com/ShobiStassen/VIA.git

# %%
adata = sc.read('/content/drive/MyDrive/Gastric/NKT/Data/Gastric_CD8_Pos_anno.h5ad')
adata

# %%
sc.pp.neighbors(adata, use_rep="X_scVI", metric="cosine",n_neighbors=15, random_state = 112)
sc.tl.leiden(adata)
sc.tl.paga(adata)
sc.pl.paga(adata, plot=False)  # remove `plot=False` if you want to see the coarse-grained graph
sc.tl.umap(adata,init_pos='paga')

# %% [markdown]
# # VIA

# %%
tsnem = adata.obsm['X_umap']
# 细胞类型标签
true_label = adata.obs['T/NK_celltype'].tolist()
# Umap标签
embedding = adata.obsm['X_umap']

# %%
adata.obs['T/NK_celltype']

# %%
#define parameters
ncomps, knn, random_seed, dataset, root_user  =30,20, 0,'T/NK_celltype', ['CD8.T.Early_Activated']

v0 = VIA(adata.obsm['X_scVI'][:, 0:ncomps], 
         true_label,   # 细胞类型标签
         jac_std_global=0.15, #控制集群的细粒度。范围0-1是合理的。值接近0将导致更多且更小的集群
         dist_std_local=1, 
         knn=knn,  # 图的最近邻的已知数
         cluster_graph_pruning_std=0.15, 
         too_big_factor=0.3, # 超过整个细胞群体30%的亚群将被重新聚类。值0.1-0.3运行良好
         root_user=root_user, # 起始细胞
         preserve_disconnected=True, # 尝试链接起由于剪枝带来的碎片，如果轨迹存在断裂情况，设置为Fasle
         dataset='group', # Group ID，会基于提供的 root_user 参数的类型进行设置
         random_seed=random_seed)#, piegraph_arrow_head_width=0.2,             piegraph_edgeweight_scalingfactor=1.0)  
v0.run_VIA()

# %%
# VIA graph 
# 细胞组成图和伪时序图

fig, ax, ax2= draw_piechart_graph(via0=v0, 
                  type_data='pt', # 可选择‘pt'(可视化伪时序). or ‘gene’
                  title='Toy multifurcation', #
                  cmap='viridis', # 颜色
                  ax_text=False, # 如果不需要细胞类型标签可以选择False(别选True，太辣眼睛了)
                  gene_exp='', # 如果需要绘制基因强度，可以在输入基因名
                  alpha_edge=0.4,  # 不知道有啥用
                  linewidth_edge=1.5,  # 设置线的宽度
                  edge_color='green',  # 设置线的颜色
                  headwidth_arrow=0.09, # 设置箭头大小
                  )
fig.set_size_inches(10,5)

# %%
f, ax = plot_scatter(embedding = embedding,  #二维坐标矩阵
            labels = v0.true_label, # 标签或者字符串列表（用于可视化对象）
            cmap = 'rainbow',  # 颜色标签
            s = 5,     # 控制
            alpha = 0.4,   # 控制亚群颜色深浅度，数字越小越浅。
            edgecolors = 'None',
            title= '',  # title设置
            text_labels = True, # 是否显示亚群的标签
            color_dict = None,  # list，给亚群提供颜色信息
            categorical = None, 
            via_object = None, 
            sc_index_terminal_states=None, 
            true_labels=[]
            ) # 绘制散点图

# %%
f, ax = plot_scatter(embedding = embedding, labels = v0.single_cell_pt_markov)

# %%
via_streamplot(v0,
        embedding,
        scatter_size = 50, # 散点大小
        scatter_alpha = 0.5,  # 散点深浅调整
        marker_edgewidth = 0.1, # 散点轮廓
        density_stream = 2,  # 场线间距
        smooth_transition = 1, # 概率转移矩阵平滑参数
        color_scheme = 'time',  #设置为time则显示伪时序
        add_outline_clusters = False, # 不知道有啥用
        )

# %%
fig, ax, ax1 = draw_trajectory_gams(via_coarse=v0,     # 不要想太多，这个和下面参数都是v0
                    via_fine= v0,
                    embedding=embedding,  # 可视化二维坐标
                    draw_all_curves=False, # 如果聚类图有太多的边，无法以可视化的方式进行投影，那么将其设置为 False，以获得图形路径的简化视图
                    dpi=80,
                    arrow_width_scale_factor = 15, # 箭头宽度比例因子
                    linewidth = 2, # 线宽
                    )

# %%
df_subset = pd.DataFrame(adata.obsm['X_scVI'][:, 0:1], columns=['GLAT4'])
f, axs = get_gene_expression(via0=v0, gene_exp=df_subset, cmap='jet',linewidth=2, fontsize_=8, spline_order=4, n_splines=10) #default parameters shown here for retrieving gene expression
f.set_size_inches(10,3)

# %%
adata.obs['dpt'] = v0.single_cell_pt_markov
sc.pl.umap(adata,color=['dpt'])

# %% [markdown]
# ## 箱线图
#
# 参考：https://starlitnightly.github.io/bioinformatic_tutorial/PLOT/plot_2.html

# %%
#获取箱子位置的函数，如果是两个箱子，那么其应该是在坐标两侧根据width分隔
#如果是三个箱子，那么坐标的位置箱子width各占一半，再根据width进行分隔
#设置间距函数
def ticks_range(x,width):
    nticks=[]
    pticks=[]
    start=-0
    end=0
    for i in range(x//2):
        nticks.append(start-width)
        start-=width
        pticks.append(end+width)
        end+=width
    if x%2==0:
        ticks=nticks+pticks
    elif x%2==1:
        ticks=nticks+[0]+pticks
    return ticks

# %%
#两个样本的情况使用该函数
def ticks_range(x,width):
    nticks=[]
    pticks=[]
    start=-(x//2)
    end=(x//2)
    for i in range(x//2):
        nticks.append(start+width)
        start+=width
        pticks.append(end-width)
        end-=width
    if x%2==0:
        ticks=nticks+pticks
    elif x%2==1:
        ticks=nticks+[0]+pticks
    return ticks

# %%
import random
import matplotlib.patches as mpatches

data = adata.obs

#获取需要分割的数据
hue='T/NK_celltype'
hue_datas=list(set(data[hue]))

#获取箱线图的横坐标
x='Sample'
ticks=list(set(data[x]))

#在这个数据中，我们有6个不同的癌症，每个癌症都有2个基因（2个箱子）
#所以我们需要得到每一个基因的6个箱线图位置，6个散点图的抖动
plot_data1={}#字典里的每一个元素就是每一个基因的所有值
plot_data_random1={}#字典里的每一个元素就是每一个基因的随机20个值
plot_data_xs1={}#字典里的每一个元素就是每一个基因的20个抖动值


#箱子的参数
width=0.4 # 箱子的间隔
length = 0.3 # 箱子的宽度
y='dpt'
for hue_data,num in zip(hue_datas,ticks_range(len(hue_datas),width)):
    data_a=[]
    data_a_random=[]
    data_a_xs=[]
    for i,k in zip(ticks,range(len(ticks))):
        test_data=data.loc[((data[x]==i)&(data[hue]==hue_data)),y].tolist()
        data_a.append(test_data)
        if len(test_data)<50:
            data_size=len(test_data)
        else:
            data_size=50
        random_data=random.sample(test_data,data_size)
        data_a_random.append(random_data)
        data_a_xs.append(np.random.normal(k*len(hue_datas)+num, 0.04, len(random_data)))
    data_a=np.array(data_a)
    data_a_random=np.array(data_a_random)
    plot_data1[hue_data]=data_a 
    plot_data_random1[hue_data]=data_a_random
    plot_data_xs1[hue_data]=data_a_xs

# %%
fig, ax = plt.subplots(figsize=(4,4))
#色卡
palette=['#a64d79','#674ea7','#1F577B', '#A56BA7', '#E0A7C8']
#绘制箱线图
for hue_data,hue_color,num in zip(hue_datas,palette,ticks_range(len(hue_datas),width)):
    b1=ax.boxplot(plot_data1[hue_data], 
                  positions=np.array(range(len(ticks)))*len(hue_datas)+num, 
                  sym='', 
                  widths=length,)
    plt.setp(b1['boxes'], color=hue_color)
    plt.setp(b1['whiskers'], color=hue_color)
    plt.setp(b1['caps'], color=hue_color)
    plt.setp(b1['medians'], color=hue_color)

    clevels = np.linspace(0., 1., len(plot_data_random1[hue_data]))
    for x, val, clevel in zip(plot_data_xs1[hue_data], plot_data_random1[hue_data], clevels):
        plt.scatter(x, val,c=hue_color,alpha=0.4)

#坐标轴字体
fontsize=10
#修改横坐标
ax.set_xticks(range(0, len(ticks) * len(hue_datas), len(hue_datas)), ['Celltype'],fontsize=fontsize)
#修改纵坐标
yticks=ax.get_yticks()
ax.set_yticks(yticks[yticks>=0],yticks[yticks>=0],fontsize=fontsize)


# 标签生成
labels = hue_datas  #legend标签列表，上面的color即是颜色列表
color = palette
#用label和color列表生成mpatches.Patch对象，它将作为句柄来生成legend
patches = [ mpatches.Patch(color=color[i], label="{:s}".format(labels[i]) ) for i in range(len(hue_datas)) ] 
ax.legend(handles=patches,bbox_to_anchor=(1, 0.55), ncol=1,fontsize=fontsize)

#设置标题
ax.set_title('Dpt Score',fontsize=fontsize+2)
#设置spines可视化情况
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)

#fig.savefig(current_path+"figures/fig_boxplot.png",dpi=300,bbox_inches = 'tight')

# %% [markdown]
# # 基因表达

# %%
sc.pl.umap(adata,color=['CD8A','GZMA','GZMB','CTLA4','TIGIT','CXCL13','PDCD1'])

# %% [markdown]
# # Loading

# %%
# !pip install scanpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 63.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 69.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 7.1 MB/s eta 0:00:00
# ...
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82816 sha256=0c8899d98ebf0364ab8e38506e94a0f56ef10bf8b8e004558eba061c9586096d
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
# ...

# %%
import pandas as pd 
import scanpy as sc
import numpy as np
import anndata as ad

# %%
adata_all = sc.read_h5ad("/content/drive/MyDrive/Gastric/Data/Gastric_Origin.h5ad")
adata_all
# Out:
# AnnData object with n_obs × n_vars = 63398 × 32559
#     obs: 'Group_number', 'Sample', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', '_scvi_batch', '_scvi_labels', 'leiden', 'major_celltype', 'Person'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'Group_number_colors', 'Person_colors', 'Sample_colors', '_scvi_manager_uuid', '_scvi_uuid', 'dendrogram_Group_number', 'dendrogram_leiden', 'dendrogram_major_celltype', 'hvg', 'leiden', 'leiden_colors', 'leiden_sizes', 'log1p', 'major_celltype_colors', 'neighbors', 'paga', 'pca', 'umap'
#     obsm: 'X_pca', 'X_scVI', 'X_umap'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata_CD = sc.read('/content/drive/MyDrive/Gastric/NKT/Data/Gastric_NKT_anno.h5ad')
adata_CD8 = adata_CD[adata_CD.obs['T/NK_type']=='CD8']
adata_CD8
# Out:
# View of AnnData object with n_obs × n_vars = 6268 × 2000
#     obs: 'Group_number', 'Sample', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', '_scvi_batch', '_scvi_labels', 'leiden', 'major_celltype', 'Person', 'T/NK_celltype', 'T/NK_type'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'Group_number_colors', 'Person_colors', 'Sample_colors', 'T', '_scvi_manager_uuid', '_scvi_uuid', 'dendrogram_Group_number', 'dendrogram_T', 'dendrogram_leiden', 'dendrogram_major_celltype', 'hvg', 'leiden', 'leiden_colors', 'leiden_sizes', 'log1p', 'major_celltype_colors', 'neighbors', 'paga', 'pca', 'umap'
#     obsm: 'X_pca', 'X_scVI', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata_epi = sc.read_h5ad('/content/drive/MyDrive/LIU/Data/Gastric_Epi_anno.h5ad')
adata_epi = adata_epi[adata_epi.obs['Epi_cell']!='ILC']
adata_epi
# Out:
# View of AnnData object with n_obs × n_vars = 25813 × 32559
#     obs: 'Group_number', 'Sample', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', '_scvi_batch', '_scvi_labels', 'leiden', 'major_celltype', 'Person', 'n_counts', 'Usage_1', 'Usage_2', 'Usage_3', 'Usage_4', 'Usage_5', 'Usage_6', 'max', 'Epi_cell'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'Group_number_colors', 'Person_colors', 'Sample_colors', '_scvi_manager_uuid', '_scvi_uuid', 'dendrogram_Group_number', 'dendrogram_leiden', 'dendrogram_major_celltype', 'hvg', 'leiden', 'leiden_colors', 'leiden_sizes', 'log1p', 'major_celltype_colors', 'neighbors', 'paga', 'pca', 'umap'
#     obsm: 'X_pca', 'X_scVI', 'X_umap'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata_obs = adata_all.obs
adata_obs['celltype']='None'
adata_obs.loc[adata_epi.obs.index,'celltype'] = adata_epi.obs.loc[:,'Epi_cell'].values
adata_obs.loc[adata_CD8.obs.index,'celltype'] = adata_CD8.obs.loc[:,'T/NK_celltype'].values
adata_obs
# Out:
#                       Group_number Sample  n_genes  n_genes_by_counts  \
# AAACCTGAGACCTAGG-1_0           DYM    Pos     3771               3771
# AAACCTGAGACGCACA-1_0           DYM    Pos     1084               1084
# AAACCTGAGCTCCTCT-1_0           DYM    Pos     4531               4530
# AAACCTGAGGCTCAGA-1_0           DYM    Pos      998                998
# AAACCTGCACTTAAGC-1_0           DYM    Pos     3679               3679
# ...                            ...    ...      ...                ...
# TTTGTCATCAACACCA-1_11         PC09   Para     2023               2023
# TTTGTCATCGGCGGTT-1_11         PC09   Para     3735               3735
# TTTGTCATCTCGATGA-1_11         PC09   Para     3342               3342
# TTTGTCATCTGCAAGT-1_11         PC09   Para     1547               1547
# TTTGTCATCTGTGCAA-1_11         PC09   Para      795                795
#
#                        total_counts  total_counts_mt  pct_counts_mt  \
# ...

# %%
adata_obs = adata_obs[adata_obs['celltype']!='None']
adata_obs
# Out:
#                       Group_number Sample  n_genes  n_genes_by_counts  \
# AAACCTGAGACCTAGG-1_0           DYM    Pos     3771               3771
# AAACCTGAGACGCACA-1_0           DYM    Pos     1084               1084
# AAACCTGAGCTCCTCT-1_0           DYM    Pos     4531               4530
# AAACCTGAGGCTCAGA-1_0           DYM    Pos      998                998
# AAACCTGCACTTAAGC-1_0           DYM    Pos     3679               3679
# ...                            ...    ...      ...                ...
# TTTGTCACAAGACACG-1_11         PC09   Para     1484               1484
# TTTGTCACAAGAGGCT-1_11         PC09   Para     2650               2650
# TTTGTCAGTGTAACGG-1_11         PC09   Para     1530               1530
# TTTGTCATCGGCGGTT-1_11         PC09   Para     3735               3735
# TTTGTCATCTCGATGA-1_11         PC09   Para     3342               3342
#
#                        total_counts  total_counts_mt  pct_counts_mt  \
# ...

# %%
adata = adata_all[adata_obs.index]
adata.obs = adata_obs
adata
# Out:
# AnnData object with n_obs × n_vars = 32081 × 32559
#     obs: 'Group_number', 'Sample', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', '_scvi_batch', '_scvi_labels', 'leiden', 'major_celltype', 'Person', 'celltype'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'Group_number_colors', 'Person_colors', 'Sample_colors', '_scvi_manager_uuid', '_scvi_uuid', 'dendrogram_Group_number', 'dendrogram_leiden', 'dendrogram_major_celltype', 'hvg', 'leiden', 'leiden_colors', 'leiden_sizes', 'log1p', 'major_celltype_colors', 'neighbors', 'paga', 'pca', 'umap'
#     obsm: 'X_pca', 'X_scVI', 'X_umap'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
set(adata.obs['celltype'])
# Out:
# {'CD8.EA', 'CD8.EM', 'CD8.MAIT', 'CD8.RM', 'GIM', 'GMC', 'MSC', 'PMC'}

# %% [markdown]
# # 创建并激活conda环境 导入cellphonedb

# %%
#!pip install -U omicverse
#!pip install -U numba
#!pip install --force-reinstall package_with_metadata_issue
#!pip install --force-reinstall virtualenv
#!pip uninstall numpy
# !pip install numpy==1.22
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
adata.write_h5ad('norm_log_celltype.h5ad',compression='gzip')

# %%
#!conda activate myenv
# !pip install cellphonedb
# !pip install scanpy
# !pip install -U omicverse
# !pip install -U numba

# %%
import scanpy as sc
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import omicverse as ov
import anndata
import os

sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# Creating directory /root/.config/bioservices
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in _dep_map(self)
#    3107         try:
# -> 3108             return self.__dep_map
#    3109         except AttributeError:
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in __getattr__(self, attr)
#    2900         if attr.startswith('_'):
# -> 2901             raise AttributeError(attr)
#    2902         return getattr(self._provider, attr)
#
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in _parsed_pkg_info(self)
#    3098         try:
# ...

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
# Out:
# filtered out 4057 genes that are detected in less than 3 cells

# %%
adata1=ad.AnnData(adata.X,obs=pd.DataFrame(index=adata.obs.index),
                          var=pd.DataFrame(index=adata.var.index))
adata1.write_h5ad('/content/norm_log.h5ad',compression='gzip')
adata1
# Out:
# AnnData object with n_obs × n_vars = 32081 × 28502

# %%
#meta导出
df_meta = pd.DataFrame(data={'Cell':list(adata[adata1.obs.index].obs.index),
                             'cell_type':[ i for i in adata[adata1.obs.index].obs['celltype']]
                            })
df_meta.set_index('Cell', inplace=True)
df_meta.to_csv('/content/meta.tsv', sep = '\t')

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !git clone https://github.com/ventolab/cellphonedb-data.git
# Out:
# Cloning into 'cellphonedb-data'...
# remote: Enumerating objects: 185, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 185 (delta 27), reused 42 (delta 13), pack-reused 115
# Receiving objects: 100% (185/185), 26.23 MiB | 37.47 MiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %%
# !pip install numba
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
cpdb_file_path = '/content/cellphonedb-data/cellphonedb.zip'
meta_file_path = os.getcwd()+'/meta.tsv'
counts_file_path = os.getcwd()+'/norm_log.h5ad'
microenvs_file_path = None
out_path =os.getcwd()+'/test_cellphone'

# %%
from cellphonedb.src.core.methods import cpdb_statistical_analysis_method

deconvoluted, means, pvalues, significant_means = cpdb_statistical_analysis_method.call(
    cpdb_file_path = cpdb_file_path,                 # mandatory: CellPhoneDB database zip file.
    meta_file_path = meta_file_path,                 # mandatory: tsv file defining barcodes to cell label.
    counts_file_path = counts_file_path,             # mandatory: normalized count matrix.
    counts_data = 'hgnc_symbol',                     # defines the gene annotation in counts matrix.
    microenvs_file_path = microenvs_file_path,       # optional (default: None): defines cells per microenvironment.
    iterations = 1000,                               # denotes the number of shufflings performed in the analysis.
    threshold = 0.1,                                 # defines the min % of cells expressing a gene for this to be employed in the analysis.
    threads = 4,                                     # number of threads to use in the analysis.
    debug_seed = 42,                                 # debug randome seed. To disable >=0.
    result_precision = 3,                            # Sets the rounding for the mean values in significan_means.
    pvalue = 0.05,                                   # P-value threshold to employ for significance.
    subsampling = False,                             # To enable subsampling the data (geometri sketching).
    subsampling_log = False,                         # (mandatory) enable subsampling log1p for non log-transformed data inputs.
    subsampling_num_pc = 100,                        # Number of componets to subsample via geometric skectching (dafault: 100).
    subsampling_num_cells = 1000,                    # Number of cells to subsample (integer) (default: 1/3 of the dataset).
    separator = '|',                                 # Sets the string to employ to separate cells in the results dataframes "cellA|CellB".
    debug = False,                                   # Saves all intermediate tables employed during the analysis in pkl format.
    output_path = out_path,                          # Path to save results.
    output_suffix = None                             # Replaces the timestamp in the output files by a user defined string in the  (default: None).
    )
# Out:
# Reading user files...
# The following user files were loaded successfully:
# /content/norm_log.h5ad
# /content/meta.tsv
# [ ][CORE][17/05/23-09:03:31][INFO] [Cluster Statistical Analysis] Threshold:0.1 Iterations:1000 Debug-seed:42 Threads:4 Precision:3
# [ ][CORE][17/05/23-09:03:31][WARNING] Debug random seed enabled. Set to 42
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-32-2e8a837c9233> in <cell line: 3>()
#       1 from cellphonedb.src.core.methods import cpdb_statistical_analysis_method
#       2
# ----> 3 deconvoluted, means, pvalues, significant_means = cpdb_statistical_analysis_method.call(
#       4     cpdb_file_path = cpdb_file_path,                 # mandatory: CellPhoneDB database zip file.
#       5     meta_file_path = meta_file_path,                 # mandatory: tsv file defining barcodes to cell label.
#
# ...

# %%
interaction=ov.single.cpdb_network_cal(adata = adata,pvals = pvalues,celltype_key = "cell_labels",)
